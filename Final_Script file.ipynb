# %% [markdown]
# # Data Analysis on Womens Clothing Reviews:

# %% [markdown]
# ## Importing csv file for Data analysis:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
p=pd.read_csv('Womens Clothing E-Commerce Reviews.csv')

# %% [markdown]
# # Reading our csv file using Pandas DataFrame:

# %%
cp=pd.DataFrame(p)

# %%
cp
# Out:
#        Unnamed: 0  Clothing ID  Age  \
# 0               0          767   33
# 1               1         1080   34
# 2               2         1077   60
# 3               3         1049   50
# 4               4          847   47
# ...           ...          ...  ...
# 23481       23481         1104   34
# 23482       23482          862   48
# 23483       23483         1104   31
# 23484       23484         1084   28
# 23485       23485         1104   52
#
#                                                    Title  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                Some major design flaws
# 3                                       My favorite buy!
# 4                                       Flattering shirt
# ...                                                  ...
# 23481                     Great dress for many occasions
# 23482                         Wish it was made of cotton
# ...

# %% [markdown]
# # Displaying top 5 rows from Dataset:

# %%
cp.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# ...

# %% [markdown]
# # Displaying last 5 rows from Dataset:

# %%
cp.tail()
# Out:
#        Unnamed: 0  Clothing ID  Age  \
# 23481       23481         1104   34
# 23482       23482          862   48
# 23483       23483         1104   31
# 23484       23484         1084   28
# 23485       23485         1104   52
#
#                                                    Title  \
# 23481                     Great dress for many occasions
# 23482                         Wish it was made of cotton
# 23483                              Cute, but see through
# 23484  Very cute dress, perfect for summer parties an...
# 23485                    Please make more like this one!
#
#                                              Review Text  Rating  \
# 23481  I was very happy to snag this dress at such a ...       5
# 23482  It reminds me of maternity clothes. soft, stre...       3
# 23483  This fit well, but the top was very see throug...       3
# 23484  I bought this dress for a wedding i have this ...       3
# 23485  This dress in a lovely platinum is feminine an...       5
#
# ...

# %% [markdown]
# # Displaying top 10 rows From Dataset:

# %%
#passing argument to head
cp.head(10)
# Out:
#    Unnamed: 0  Clothing ID  Age                                 Title  \
# 0           0          767   33                                   NaN
# 1           1         1080   34                                   NaN
# 2           2         1077   60               Some major design flaws
# 3           3         1049   50                      My favorite buy!
# 4           4          847   47                      Flattering shirt
# 5           5         1080   49               Not for the very petite
# 6           6          858   39                  Cagrcoal shimmer fun
# 7           7          858   39  Shimmer, surprisingly goes with lots
# 8           8         1077   24                            Flattering
# 9           9         1077   34                     Such a fun dress!
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# ...

# %% [markdown]
# # Displaing last 10 rows From Dataset:

# %%
#passing argument to tail
cp.tail(10)
# Out:
#        Unnamed: 0  Clothing ID  Age  \
# 23476       23476          522   27
# 23477       23477         1094   39
# 23478       23478         1104   32
# 23479       23479         1005   42
# 23480       23480          862   35
# 23481       23481         1104   34
# 23482       23482          862   48
# 23483       23483         1104   31
# 23484       23484         1084   28
# 23485       23485         1104   52
#
#                                                    Title  \
# 23476                                            Cheeky!
# 23477                                         Entrancing
# 23478                                       Unflattering
# 23479                                  What a fun piece!
# 23480                                                NaN
# 23481                     Great dress for many occasions
# 23482                         Wish it was made of cotton
# 23483                              Cute, but see through
# ...

# %% [markdown]
# # Attributes:

# %% [markdown]
# ### Knowing the shape our dataset

# %%
cp.shape
# Out:
# (23486, 11)

# %% [markdown]
# ### Accessing column attributes

# %%
cp.columns
# Out:
# Index(['Unnamed: 0', 'Clothing ID', 'Age', 'Title', 'Review Text', 'Rating',
#        'Recommended IND', 'Positive Feedback Count', 'Division Name',
#        'Department Name', 'Class Name'],
#       dtype='object')

# %% [markdown]
# ### Knowing the datatypes of columns

# %%
cp.dtypes
# Out:
# Unnamed: 0                  int64
# Clothing ID                 int64
# Age                         int64
# Title                      object
# Review Text                object
# Rating                      int64
# Recommended IND             int64
# Positive Feedback Count     int64
# Division Name              object
# Department Name            object
# Class Name                 object
# dtype: object

# %% [markdown]
# # Describing basic statistics of Dataset:

# %%
#by using describe() method we can achive this 
cp.describe()
# Out:
#          Unnamed: 0   Clothing ID           Age        Rating  \
# count  23486.000000  23486.000000  23486.000000  23486.000000
# mean   11742.500000    918.118709     43.198544      4.196032
# std     6779.968547    203.298980     12.279544      1.110031
# min        0.000000      0.000000     18.000000      1.000000
# 25%     5871.250000    861.000000     34.000000      4.000000
# 50%    11742.500000    936.000000     41.000000      5.000000
# 75%    17613.750000   1078.000000     52.000000      5.000000
# max    23485.000000   1205.000000     99.000000      5.000000
#
#        Recommended IND  Positive Feedback Count
# count     23486.000000             23486.000000
# mean          0.822362                 2.535936
# std           0.382216                 5.702202
# min           0.000000                 0.000000
# 25%           1.000000                 0.000000
# 50%           1.000000                 1.000000
# 75%           1.000000                 3.000000
# ...

# %% [markdown]
# # Rounding up the values:

# %%
round(cp.describe(),2)
# Out:
#        Unnamed: 0  Clothing ID       Age    Rating  Recommended IND  \
# count    23486.00     23486.00  23486.00  23486.00         23486.00
# mean     11742.50       918.12     43.20      4.20             0.82
# std       6779.97       203.30     12.28      1.11             0.38
# min          0.00         0.00     18.00      1.00             0.00
# 25%       5871.25       861.00     34.00      4.00             1.00
# 50%      11742.50       936.00     41.00      5.00             1.00
# 75%      17613.75      1078.00     52.00      5.00             1.00
# max      23485.00      1205.00     99.00      5.00             1.00
#
#        Positive Feedback Count
# count                 23486.00
# mean                      2.54
# std                       5.70
# min                       0.00
# 25%                       0.00
# 50%                       1.00
# 75%                       3.00
# max                     122.00

# %% [markdown]
# # Displaying particular column From Dataset:

# %%
cp['Age']
# Out:
# 0        33
# 1        34
# 2        60
# 3        50
# 4        47
#          ..
# 23481    34
# 23482    48
# 23483    31
# 23484    28
# 23485    52
# Name: Age, Length: 23486, dtype: int64

# %% [markdown]
# # Number of Positive Feedbacks:

# %%
cp['Positive Feedback Count'].sum()
# Out:
# 59559

# %%
#mean(),std(),max(),min(),count()

# %% [markdown]
# # Listing the Department Names:

# %%
cp['Department Name'].value_counts()
# Out:
# Tops        10468
# Dresses      6319
# Bottoms      3799
# Intimate     1735
# Jackets      1032
# Trend         119
# Name: Department Name, dtype: int64

# %% [markdown]
# # Addition of Two Particular Columns:

# %%
cp['Recommended IND']+ cp['Positive Feedback Count']
# Out:
# 0         1
# 1         5
# 2         0
# 3         1
# 4         7
#          ..
# 23481     1
# 23482     1
# 23483     1
# 23484     3
# 23485    23
# Length: 23486, dtype: int64

# %% [markdown]
# # Sorting using sort_values()

# %%
cp.sort_values(['Age'],ascending=True)
# Out:
#        Unnamed: 0  Clothing ID  Age                              Title  \
# 22364       22364         1072   18          I get so many compliments
# 8858         8858         1094   18                               Love
# 22390       22390          868   18  A little big, but so comfortable!
# 19704       19704         1008   18                           Stunning
# 9971         9971         1080   19                                NaN
# ...           ...          ...  ...                                ...
# 6543         6543         1095   94                                NaN
# 18036       18036         1094   94                                NaN
# 18563       18563         1094   94                       Great dress!
# 8327         8327         1078   99                   Beachy and boho!
# 11545       11545          949   99                                NaN
#
#                                              Review Text  Rating  \
# ...

# %% [markdown]
# # Creating DataFrame using numpy array:

# %%
data=np.array([[1,4],[2,5],[3,5]])

# %%
data
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 5]])

# %% [markdown]
# ### Creating DataFrame using above array

# %%
d=pd.DataFrame(data)

# %%
d
# Out:
#    0  1
# 0  1  4
# 1  2  5
# 2  3  5

# %% [markdown]
# ### Giving names to rows and columns to the above DataFrame:

# %%
pd.DataFrame(data,index=['a','b','c'],columns=['p','c'])
# Out:
#    p  c
# a  1  4
# b  2  5
# c  3  5

# %% [markdown]
# ### Creating DataFrame using Dictionary:

# %%
names=['a','b','c','d']
Age=[5,6,7,8]
bcp={'NAME':names,'AGE':Age}
pd.DataFrame(bcp)
# Out:
#   NAME  AGE
# 0    a    5
# 1    b    6
# 2    c    7
# 3    d    8

# %% [markdown]
# # Slicing in DataFrame:

# %%
cp[2:8]
# Out:
#    Unnamed: 0  Clothing ID  Age                                 Title  \
# 2           2         1077   60               Some major design flaws
# 3           3         1049   50                      My favorite buy!
# 4           4          847   47                      Flattering shirt
# 5           5         1080   49               Not for the very petite
# 6           6          858   39                  Cagrcoal shimmer fun
# 7           7          858   39  Shimmer, surprisingly goes with lots
#
#                                          Review Text  Rating  Recommended IND  \
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
# 5  I love tracy reese dresses, but this one is no...       2                0
# 6  I aded this in my basket at hte last mintue to...       5                1
# ...

# %% [markdown]
# # Displaying the Data which is having the Rating 4 and above:

# %%
rating=cp[cp['Rating']>=4]

# %%
rating
# Out:
#        Unnamed: 0  Clothing ID  Age                            Title  \
# 0               0          767   33                              NaN
# 1               1         1080   34                              NaN
# 3               3         1049   50                 My favorite buy!
# 4               4          847   47                 Flattering shirt
# 6               6          858   39             Cagrcoal shimmer fun
# ...           ...          ...  ...                              ...
# 23477       23477         1094   39                       Entrancing
# 23479       23479         1005   42                What a fun piece!
# 23480       23480          862   35                              NaN
# 23481       23481         1104   34   Great dress for many occasions
# 23485       23485         1104   52  Please make more like this one!
#
#                                              Review Text  Rating  \
# 0      Absolutely wonderful - silky and sexy and comf...       4
# ...

# %% [markdown]
# # Finding specific row:

# %%
cp.loc[6]
# Out:
# Unnamed: 0                                                                 6
# Clothing ID                                                              858
# Age                                                                       39
# Title                                                   Cagrcoal shimmer fun
# Review Text                I aded this in my basket at hte last mintue to...
# Rating                                                                     5
# Recommended IND                                                            1
# Positive Feedback Count                                                    1
# Division Name                                                 General Petite
# Department Name                                                         Tops
# Class Name                                                             Knits
# Name: 6, dtype: object

# %%
#Displaying range of rows 
cp.loc[1:6]
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
# 5           5         1080   49  Not for the very petite
# 6           6          858   39     Cagrcoal shimmer fun
#
#                                          Review Text  Rating  Recommended IND  \
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
# 5  I love tracy reese dresses, but this one is no...       2                0
# 6  I aded this in my basket at hte last mintue to...       5                1
#
# ...

# %%
cp
# Out:
#        Unnamed: 0  Clothing ID  Age  \
# 0               0          767   33
# 1               1         1080   34
# 2               2         1077   60
# 3               3         1049   50
# 4               4          847   47
# ...           ...          ...  ...
# 23481       23481         1104   34
# 23482       23482          862   48
# 23483       23483         1104   31
# 23484       23484         1084   28
# 23485       23485         1104   52
#
#                                                    Title  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                Some major design flaws
# 3                                       My favorite buy!
# 4                                       Flattering shirt
# ...                                                  ...
# 23481                     Great dress for many occasions
# 23482                         Wish it was made of cotton
# ...

# %% [markdown]
# # Removing  duplicates values of a particular column:

# %%
cp.drop_duplicates(subset='Clothing ID',keep=False,inplace=True)

# %%
cp
# Out:
#        Unnamed: 0  Clothing ID  Age  \
# 29             29            4   28
# 43             43           89   67
# 122           122         1196   29
# 138           138          126   34
# 157           157          523   43
# ...           ...          ...  ...
# 23249       23249          387   34
# 23318       23318          345   39
# 23425       23425          430   23
# 23438       23438          181   68
# 23476       23476          522   27
#
#                                                Title  \
# 29                              Great layering piece
# 43                    Some things you should know...
# 122                                              NaN
# 138    Feminine alternative to your shapeless puffer
# 157                              Australian sizing!!
# ...                                              ...
# 23249                Don't even know they are there!
# 23318                         Adjustable and stylish
# ...

# %% [markdown]
# # Look up a random review:

# %%
cp['Review Text'][43]
# Out:
# 'First, this is thermal ,so naturally i didn\'t expect super sheer, but it is. really sheer light fabric. i like it, but be prepared for considering who you might run into if you walk around the house in it. second, it is large. i ordered the size 0 and it\'s a nice oversized fit for my 5\'3" 125 pounds. i wouldn\'t want to go larger. along with being sheer, the fabric is easily stretched, which i don\'t mind in this case. finally, the color. it looks white on my monitor and shows a colorful blue dot'

# %%
# List Class Names
cp['Class Name'].value_counts()
# Out:
# Lounge            103
# Swim               90
# Intimates          80
# Sleep              45
# Shorts             31
# Legwear            30
# Layering           24
# Dresses            14
# Trend              14
# Knits               9
# Pants               8
# Sweaters            8
# Jeans               7
# Jackets             6
# Outerwear           6
# Fine gauge          4
# Skirts              3
# Blouses             3
# Casual bottoms      2
# Chemises            1
# Name: Class Name, dtype: int64

# %% [markdown]
# # Data cleaning:

# %%
#.dropna(how='any') to drop if any value in the row has a NaN
#.dropna(how='all') to drop if all the values in the row are NaN
cp1=cp.dropna(how='any')

# %%
cp1
# Out:
#        Unnamed: 0  Clothing ID  Age  \
# 29             29            4   28
# 43             43           89   67
# 138           138          126   34
# 157           157          523   43
# 171           171          329   46
# ...           ...          ...  ...
# 23239       23239          487   35
# 23249       23249          387   34
# 23318       23318          345   39
# 23438       23438          181   68
# 23476       23476          522   27
#
#                                                Title  \
# 29                              Great layering piece
# 43                    Some things you should know...
# 138    Feminine alternative to your shapeless puffer
# 157                              Australian sizing!!
# 171                              Comfy and adorable!
# ...                                              ...
# 23239                                    Coincidence
# 23249                Don't even know they are there!
# ...

# %%
cp2=cp1.head(10)

# %%
cp2
# Out:
#      Unnamed: 0  Clothing ID  Age  \
# 29           29            4   28
# 43           43           89   67
# 138         138          126   34
# 157         157          523   43
# 171         171          329   46
# 187         187          596   41
# 216         216          305   46
# 275         275         1182   37
# 363         363          580   60
# 392         392          746   34
#
#                                              Title  \
# 29                            Great layering piece
# 43                  Some things you should know...
# 138  Feminine alternative to your shapeless puffer
# 157                            Australian sizing!!
# 171                            Comfy and adorable!
# 187                                 Modern comfort
# 216                                     Very small
# 275                                      Great tee
# 363                           Nice thin sweatshirt
# 392                    Lovely fabric but tiny hips
#
# ...

# %% [markdown]
# ### This is how many Null Values in the Dataset

# %%
p.isnull()
# Out:
#        Unnamed: 0  Clothing ID    Age  Title  Review Text  Rating  \
# 0           False        False  False   True        False   False
# 1           False        False  False   True        False   False
# 2           False        False  False  False        False   False
# 3           False        False  False  False        False   False
# 4           False        False  False  False        False   False
# ...           ...          ...    ...    ...          ...     ...
# 23481       False        False  False  False        False   False
# 23482       False        False  False  False        False   False
# 23483       False        False  False  False        False   False
# 23484       False        False  False  False        False   False
# 23485       False        False  False  False        False   False
#
#        Recommended IND  Positive Feedback Count  Division Name  \
# 0                False                    False          False
# ...

# %% [markdown]
# # This is how many number of reviews that where not present in Dataset:

# %%
pd.isna(cp['Review Text']).sum()
# Out:
# 26

# %% [markdown]
# # Plotting:

# %% [markdown]
# ### Plotting Histogram

# %%
cp['Rating'].plot(kind='hist');

# %% [markdown]
# ### Rating Distribution Plot:

# %%
ratingarr= np.arange(1, 6, 1)

#Creating histogram
plt.hist(cp['Rating'], bins = ratingarr, alpha =1, edgecolor='black', linewidth =3, color ='darkblue', density= 1)

#Add labels and title
plt.xlabel("Rating")
plt.ylabel("Rating Probability Density")
plt.title("Rating Distribution")

#Set x axis ticks to match bins
plt.xticks(ratingarr)

plt.show()

# %% [markdown]
# # Plotting pie chart for Division name,Department name and Class name:

# %%
#Create wedges and corresponding labels for column in dataframe.
def NameCount (insidedataframe, column):
    #Store unique entries 
    names = insidedataframe[column].unique()
    #remove nans
    names = [x for x in names if str(x) != 'nan']
    #Create array to store values
    count = np.empty(len(names))
    #Store recurrence of each value
    for i in range(len(names)):
        count[i] = p[(p[column] == names[i])].shape[0]
    return names, count

# %%
#Division
div_name, div_count = NameCount(p, 'Division Name')
#Department 
dep_name, dep_count = NameCount(p, 'Department Name')
#Class
class_name, class_count = NameCount(p, 'Class Name')

# %%
plt.pie(div_count, labels=div_name, autopct='%1.2f%%', shadow=True, radius= 1)
plt.title("Division", fontsize = 20)
plt.show()

# %%
plt.pie(dep_count, labels=dep_name, autopct='%1.1f%%', shadow=True, radius= 1)
plt.title("Department", fontsize = 20)
plt.show()

# %%
plt.pie(class_count, labels=class_name, autopct='%1.1f%%', shadow=True, radius= 1)
plt.title("Class", fontsize = 20)
plt.show()

# %%
p= p.dropna()
reviews=p['Review Text'].tolist()
recommend=p['Recommended IND'].tolist()
assert len(reviews) == len(recommend)

# %% [markdown]
# # Most Common Words

# %%
#create three counter objects to store positive, negative, and total counts
positive_counts = Counter()
negative_counts = Counter()
total_counts = Counter()

# %%
#loop over all the words in all the reviews and increment the count
for i in range(len(reviews)):
    if recommend[i]==1:
        for word in reviews[i].split(" "):
            positive_counts[word] +=1
            total_counts[word] +=1
    else:
        for word in reviews[i].split(" "):
            negative_counts[word] += 1
            total_counts[word] += 1

# %% [markdown]
# ### Most common words that were in positive feedbacks

# %%
positive_counts.most_common()[:10]
# Out:
# [('the', 52921),
#  ('and', 36116),
#  ('i', 36098),
#  ('a', 32033),
#  ('it', 26555),
#  ('is', 22921),
#  ('to', 17710),
#  ('this', 14869),
#  ('in', 14828),
#  ('but', 11193)]

# %% [markdown]
# ### Most common words that were in negative feedbacks

# %%
negative_counts.most_common()[:12]
# Out:
# [('the', 14059),
#  ('i', 7833),
#  ('and', 7293),
#  ('it', 6708),
#  ('a', 6116),
#  ('is', 4296),
#  ('to', 4036),
#  ('was', 3705),
#  ('this', 3609),
#  ('in', 3308),
#  ('but', 3117),
#  ('on', 2601)]

# %% [markdown]
# # word cloud

# %%
import seaborn as sns 
from PIL import Image
from wordcloud import WordCloud,STOPWORDS,ImageColorGenerator
from os import path

# %%
#Store reviews in list
review_text = np.array(p['Review Text'])

# %%
word_cloud_0 = WordCloud(background_color="white", max_font_size= 200).generate(review_text[138])
#Display the image
plt.imshow(word_cloud_0, interpolation='sinc')
plt.axis("off")
plt.show()

# %%
word_cloud_1 = WordCloud(background_color="white", max_font_size= 100).generate(review_text[1])
#Display the image
plt.imshow(word_cloud_1, interpolation='hanning')
plt.axis("off")
plt.show()

# %%
word_cloud_2 = WordCloud(background_color="white", max_font_size= 100).generate(review_text[10])
#Display the image
plt.imshow(word_cloud_2, interpolation='lanczos')
plt.axis("off")
plt.show()

# %%
word_cloud_3 = WordCloud(background_color="white", max_font_size= 100).generate(review_text[157])
#Display the image
plt.imshow(word_cloud_3, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # Sentiment Analysis:

# %%
rvt=np.array(cp['Review Text'])

# %%
positive_words=['love','good','great','amazing','super','smooth','fits','nice','perfect','like']

# %%
negative_words=['hate','horrible','big','small','rough','ugly','expensive','damage','never']

# %%
sentiment=np.zeros(len(rvt))

# %%
import re      #Regular Expression
for j in range(len(positive_words)):
    for k in range(len(rvt)):
        rv=re.sub("[^\w]"," ",str(rvt[k])).split()
        for p in range(len(rv)):
            if positive_words[j]==rv[p]:
                sentiment[p] += 1

# %% [markdown]
# ### This is how many Number of positive words which were in review text

# %%
np.sum(sentiment)
# Out:
# 650.0

# %%
import re
for j in range(len(negative_words)):
    for k in range(len(rvt)):
        rv=re.sub("[^\w]"," ",str(rvt[k])).split()
        for p in range(len(rv)):
            if negative_words[j]==rv[p]:
                sentiment[p] += 1

# %% [markdown]
# ### This is how many Number of negative words which were in review text

# %%
np.sum(sentiment)
# Out:
# 821.0
